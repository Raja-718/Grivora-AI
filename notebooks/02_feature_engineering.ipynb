# %% [markdown]
# # 02 - Feature Engineering
# Create and transform features for ML.

# %%
import pandas as pd
import sys
sys.path.append('..')
from src.data_loader import load_file
from src.preprocessor import clean_data, encode_categoricals

df = load_file('../data/raw/your_file.csv')
df = clean_data(df)
df.head()

# %%
from src.feature_engineering import add_datetime_features
# Example: add_datetime_features(df, 'date_column')
df.head()

# %%
# Encode and save
df = encode_categoricals(df)
df.to_csv('../data/processed/features.csv', index=False)
print('Saved to data/processed/features.csv')
