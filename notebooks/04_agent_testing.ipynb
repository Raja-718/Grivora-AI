# %% [markdown]
# # 04 - Agent Testing
# Test Gemini AI agents directly from this notebook.

# %%
import sys
sys.path.append('..')
from dotenv import load_dotenv
load_dotenv('../.env')

# %%
from agents.orchestrator import Orchestrator
orchestrator = Orchestrator()
print('Orchestrator ready.')

# %%
# Test analyst agent
response = orchestrator.run('What columns does this data have?', '../data/sample/sample.csv')
print(response)

# %%
# Test cleaning agent
response = orchestrator.run('Find and fix data quality issues', '../data/sample/sample.csv')
print(response)

# %%
# Test chart agent
response = orchestrator.run('What charts should I generate for this data?', '../data/sample/sample.csv')
print(response)

# %%
# Test ML agent
response = orchestrator.run('What ML model should I use to predict sales?', '../data/sample/sample.csv')
print(response)
